# %% [markdown]
# ### Evaluation Metric
#
# We evaluate solutions using:
# - Binary correctness (solved / not solved)
# - Penalization for invalid or looping transitions
#
# Rationale:
# The task does not require minimal solutions, only correctness.
